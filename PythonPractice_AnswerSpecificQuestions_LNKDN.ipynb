# %% [markdown]
# <a href="https://colab.research.google.com/github/szmtz/ds/blob/main/PythonPractice_AnswerSpecificQuestions_LNKDN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c23ac14c-8d00-4585-832a-c4fc4fb4757e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c23ac14c-8d00-4585-832a-c4fc4fb4757e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('us_baby_names.csv')

# %%
us_babies = df

# %%
us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]
# ...

# %%
us_ezra = us_babies.loc[us_babies[ 'Name' ] == 'Ezra', :]

# %%
us_ezra
# Out:
#               Id  Name  Year Gender  Count
# 1211        1212  Ezra  1880      M     39
# 3167        3168  Ezra  1881      M     44
# 5229        5230  Ezra  1882      M     41
# 7426        7427  Ezra  1883      M     28
# 9579        9580  Ezra  1884      M     43
# ...          ...   ...   ...    ...    ...
# 1745152  1745153  Ezra  2012      M   2082
# 1760654  1760655  Ezra  2013      F    151
# 1778518  1778519  Ezra  2013      M   2729
# 1793839  1793840  Ezra  2014      F    155
# 1811574  1811575  Ezra  2014      M   3372
#
# [174 rows x 5 columns]

# %%
import matplotlib

# %%
# Create a horizontal bar plot that displays the counts of my first name over the years using the plot.barh method - allows you to create a horizontal bar plot based on the data in your df
# a horizontal bar plot presents quantitative data with rectangular bars with lengths proportional to the values they represent

us_ezra.plot.barh(x = 'Year', y = 'Count')
# Out:
# <Axes: ylabel='Year'>
